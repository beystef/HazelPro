# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
import pandas as pd

# %%
from config import DATA_DIR

hazelnut_file = PROJECT_ROOT / DATA_DIR / "processed" / "hazelnut_price.csv"
weather_file = PROJECT_ROOT / DATA_DIR / "processed" / "weather_daily_1999_2025.csv"
currency_file = PROJECT_ROOT / DATA_DIR / "processed" / "usd_tl.csv"
trends_file = PROJECT_ROOT / DATA_DIR / "processed" / "trends_daily.csv"
features_file = PROJECT_ROOT / DATA_DIR / "processed" / "features.csv"
ml_file = PROJECT_ROOT / DATA_DIR / "processed" / "features_for_ml.csv"

# %%
# Load processed datasets
hazelnut = pd.read_csv(hazelnut_file, parse_dates=["Date"])
weather = pd.read_csv(weather_file, parse_dates=["date"])
currency = pd.read_csv(currency_file, parse_dates=["Date"])
trends = pd.read_csv(trends_file, parse_dates=["date"])

# %%
hazelnut.describe()
# Out:
#                       Date        Value       iValue  rolling_14d  \
# count                 9862  3777.000000  8955.000000  9128.000000
# mean   2012-07-01 12:00:00    16.579554    22.927100    22.525604
# min    1999-01-01 00:00:00     0.536056     0.536056     0.587859
# 25%    2005-10-01 06:00:00     2.420000     2.907000     2.943941
# 50%    2012-07-01 12:00:00     4.620000     5.110000     5.321429
# 75%    2019-04-01 18:00:00    12.750000    16.653333    16.586964
# max    2025-12-31 00:00:00   328.310000   328.310000   323.232619
# std                    NaN    37.820052    46.624648    45.760564
#
#        AdjustedValue    iAdjusted  rolling_14d_adjusted       USD_TL
# count    3777.000000  8955.000000           9128.000000  9862.000000
# mean        2.727991     2.786247              2.784686     6.343277
# min         0.690343     0.690343              0.730755     0.315220
# 25%         1.797479     1.955942              1.946889     1.414143
# 50%         2.665042     2.721972              2.721873     1.798403
# 75%         3.248190     3.301866              3.304607     5.698383
# max         7.895560     7.895560              7.769791    42.939500
# std         1.228727     1.214680              1.205156     9.955254

# %%
weather.describe()
# Out:
#                       date  temperature_2m_max  temperature_2m_min  \
# count                 9862         9862.000000         9862.000000
# mean   2012-07-01 12:00:00           17.466234           10.938674
# min    1999-01-01 00:00:00           -2.800000          -10.800000
# 25%    2005-10-01 06:00:00           12.400000            5.700000
# 50%    2012-07-01 12:00:00           18.000000           10.800000
# 75%    2019-04-01 18:00:00           23.200000           16.800000
# max    2025-12-31 00:00:00           35.800000           25.500000
# std                    NaN            6.950824            6.910280
#
#        apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# count               9862.000000               9862.000000        9862.000000
# mean                  17.583371                  9.815747           3.393348
# min                   -8.300000                -15.400000           0.000000
# 25%                   10.400000                  2.800000           0.000000
# 50%                   17.800000                  9.200000           0.300000
# 75%                   25.500000                 17.500000           3.900000
# max                   40.700000                 30.700000          78.700000
# std                    9.366634                  8.996720           6.416817
#
#           rain_sum  wind_speed_10m_max  et0_fao_evapotranspiration
# count  9862.000000         9862.000000                 9862.000000
# mean      3.091199           13.893977                    2.444288
# min       0.000000            4.300000                    0.180000
# 25%       0.000000           10.700000                    1.300000
# 50%       0.300000           12.850000                    2.250000
# 75%       3.500000           16.000000                    3.500000
# max      78.700000           53.700000                    6.740000
# std       6.041540            4.755491                    1.343506

# %%
currency.describe()
# Out:
#                       Date       USD_TL
# count                 9862  9862.000000
# mean   2012-07-01 12:00:00     6.343277
# min    1999-01-01 00:00:00     0.315220
# 25%    2005-10-01 06:00:00     1.414143
# 50%    2012-07-01 12:00:00     1.798403
# 75%    2019-04-01 18:00:00     5.698383
# max    2025-12-31 00:00:00    42.939500
# std                    NaN     9.955254

# %%
trends.describe()
# Out:
#                       date        trend
# count                 5510  5510.000000
# mean   2018-06-16 12:00:00    64.513640
# min    2010-12-01 00:00:00     0.000000
# 25%    2014-09-08 06:00:00    26.315634
# 50%    2018-06-16 12:00:00    47.909007
# 75%    2022-03-24 18:00:00    81.671113
# max    2025-12-31 00:00:00  1087.689728
# std                    NaN    68.207681

# %%
# Define lag periods (days)
lag_days = [30, 60, 90, 120, 180]

weather_features = ['temperature_2m_max', 'temperature_2m_min', 
                    'precipitation_sum', 'rain_sum', 'wind_speed_10m_max', 'et0_fao_evapotranspiration']

for feature in weather_features:
    for lag in lag_days:
        col_name = f"{feature}_{lag}d_lag"
        weather[col_name] = weather[feature].rolling(lag).mean().shift(lag)

# %%
# Define seasonal windows
def assign_season(month):
    if month in [3, 4, 5]:  # Spring: flowering
        return "spring"
    elif month in [6, 7, 8]:  # Nut development
        return "development"
    elif month in [9, 10]:  # Harvest
        return "harvest"
    else:
        return "off_season"

weather['season'] = weather['date'].dt.month.apply(assign_season)

# Aggregate seasonal averages/sums
seasonal_aggs = weather.groupby('season').agg({
    'temperature_2m_max': 'mean',
    'precipitation_sum': 'sum',
    'et0_fao_evapotranspiration': 'sum'
}).rename(columns={
    'temperature_2m_max': 'season_temp_max_avg',
    'precipitation_sum': 'season_precip_sum',
    'et0_fao_evapotranspiration': 'season_et0_sum'
})

print(seasonal_aggs)
# Out:
#              season_temp_max_avg  season_precip_sum  season_et0_sum
# season
# development            24.728945             6918.6         9680.45
# harvest                21.149059             7572.9         3788.98
# off_season             11.669510            11400.7         4104.89
# spring                 15.338929             7573.0         6531.25

# %%
# Flagging the extremities  
weather['heatwave_flag'] = (weather['temperature_2m_max'] > 35).astype(int)
weather['coldwave_flag'] = (weather['temperature_2m_min'] < 0).astype(int)
weather['heavy_rain_flag'] = (weather['precipitation_sum'] > 50).astype(int)

# %%
# Adding features
hazelnut['price_available'] = (~hazelnut['rolling_14d_adjusted'].isna()).astype(int)
weather['temp_missing'] = weather['temperature_2m_max'].isna().astype(int)
trends['trends_missing'] = trends['trend'].isna().astype(int)
trends['is_trend_zero'] = (trends['trend'] == 0).astype(int)

# %%
weather.rename(columns={"date": "Date"}, inplace=True)
trends.rename(columns={"date": "Date"}, inplace=True)

# %%
df = hazelnut[['Date','rolling_14d_adjusted','price_available']].merge(weather, on='Date', how='left')
df = df.merge(currency[['Date','USD_TL']], on='Date', how='left')
df = df.merge(trends, on='Date', how='left')

# %%
df.describe()
# Out:
#                       Date  rolling_14d_adjusted  price_available  \
# count                 9862           9128.000000      9862.000000
# mean   2012-07-01 12:00:00              2.784686         0.925573
# min    1999-01-01 00:00:00              0.730755         0.000000
# 25%    2005-10-01 06:00:00              1.946889         1.000000
# 50%    2012-07-01 12:00:00              2.721873         1.000000
# 75%    2019-04-01 18:00:00              3.304607         1.000000
# max    2025-12-31 00:00:00              7.769791         1.000000
# std                    NaN              1.205156         0.262478
#
#        temperature_2m_max  temperature_2m_min  apparent_temperature_max  \
# count         9862.000000         9862.000000               9862.000000
# mean            17.466234           10.938674                 17.583371
# min             -2.800000          -10.800000                 -8.300000
# 25%             12.400000            5.700000                 10.400000
# 50%             18.000000           10.800000                 17.800000
# 75%             23.200000           16.800000                 25.500000
# max             35.800000           25.500000                 40.700000
# std              6.950824            6.910280                  9.366634
#
#        apparent_temperature_min  precipitation_sum     rain_sum  \
# count               9862.000000        9862.000000  9862.000000
# mean                   9.815747           3.393348     3.091199
# min                  -15.400000           0.000000     0.000000
# 25%                    2.800000           0.000000     0.000000
# 50%                    9.200000           0.300000     0.300000
# 75%                   17.500000           3.900000     3.500000
# max                   30.700000          78.700000    78.700000
# std                    8.996720           6.416817     6.041540
#
#        wind_speed_10m_max  ...  et0_fao_evapotranspiration_120d_lag  \
# count         9862.000000  ...                          9623.000000
# mean            13.893977  ...                             2.444704
# min              4.300000  ...                             1.011083
# 25%             10.700000  ...                             1.566833
# 50%             12.850000  ...                             2.389167
# 75%             16.000000  ...                             3.311042
# max             53.700000  ...                             4.290583
# std              4.755491  ...                             0.897511
#
#        et0_fao_evapotranspiration_180d_lag  heatwave_flag  coldwave_flag  \
# count                          9503.000000    9862.000000    9862.000000
# mean                              2.436482       0.000101       0.051916
# min                               1.246722       0.000000       0.000000
# 25%                               1.760167       0.000000       0.000000
# 50%                               2.433278       0.000000       0.000000
# 75%                               3.102917       0.000000       0.000000
# max                               3.861833       1.000000       1.000000
# std                               0.696568       0.010070       0.221870
#
#        heavy_rain_flag  temp_missing       USD_TL        trend  \
# count      9862.000000        9862.0  9862.000000  5510.000000
# mean          0.000811           0.0     6.343277    64.513640
# min           0.000000           0.0     0.315220     0.000000
# 25%           0.000000           0.0     1.414143    26.315634
# 50%           0.000000           0.0     1.798403    47.909007
# 75%           0.000000           0.0     5.698383    81.671113
# max           1.000000           0.0    42.939500  1087.689728
# std           0.028471           0.0     9.955254    68.207681
#
#        trends_missing  is_trend_zero
# count          5510.0    5510.000000
# mean              0.0       0.186025
# min               0.0       0.000000
# 25%               0.0       0.000000
# 50%               0.0       0.000000
# 75%               0.0       0.000000
# max               0.0       1.000000
# std               0.0       0.389162
#
# [8 rows x 49 columns]

# %%
df.columns
# Out:
# Index(['Date', 'rolling_14d_adjusted', 'price_available', 'temperature_2m_max',
#        'temperature_2m_min', 'apparent_temperature_max',
#        'apparent_temperature_min', 'precipitation_sum', 'rain_sum',
#        'wind_speed_10m_max', 'et0_fao_evapotranspiration',
#        'temperature_2m_max_30d_lag', 'temperature_2m_max_60d_lag',
#        'temperature_2m_max_90d_lag', 'temperature_2m_max_120d_lag',
#        'temperature_2m_max_180d_lag', 'temperature_2m_min_30d_lag',
#        'temperature_2m_min_60d_lag', 'temperature_2m_min_90d_lag',
#        'temperature_2m_min_120d_lag', 'temperature_2m_min_180d_lag',
#        'precipitation_sum_30d_lag', 'precipitation_sum_60d_lag',
#        'precipitation_sum_90d_lag', 'precipitation_sum_120d_lag',
#        'precipitation_sum_180d_lag', 'rain_sum_30d_lag', 'rain_sum_60d_lag',
#        'rain_sum_90d_lag', 'rain_sum_120d_lag', 'rain_sum_180d_lag',
#        'wind_speed_10m_max_30d_lag', 'wind_speed_10m_max_60d_lag',
#        'wind_speed_10m_max_90d_lag', 'wind_speed_10m_max_120d_lag',
#        'wind_speed_10m_max_180d_lag', 'et0_fao_evapotranspiration_30d_lag',
#        'et0_fao_evapotranspiration_60d_lag',
#        'et0_fao_evapotranspiration_90d_lag',
#        'et0_fao_evapotranspiration_120d_lag',
#        'et0_fao_evapotranspiration_180d_lag', 'season', 'heatwave_flag',
#        'coldwave_flag', 'heavy_rain_flag', 'temp_missing', 'USD_TL', 'trend',
#        'trends_missing', 'is_trend_zero'],
#       dtype='object')

# %%
df.drop(columns=['apparent_temperature_max',
       'apparent_temperature_min'], inplace=True)
df.columns
# Out:
# Index(['Date', 'rolling_14d_adjusted', 'price_available', 'temperature_2m_max',
#        'temperature_2m_min', 'precipitation_sum', 'rain_sum',
#        'wind_speed_10m_max', 'et0_fao_evapotranspiration',
#        'temperature_2m_max_30d_lag', 'temperature_2m_max_60d_lag',
#        'temperature_2m_max_90d_lag', 'temperature_2m_max_120d_lag',
#        'temperature_2m_max_180d_lag', 'temperature_2m_min_30d_lag',
#        'temperature_2m_min_60d_lag', 'temperature_2m_min_90d_lag',
#        'temperature_2m_min_120d_lag', 'temperature_2m_min_180d_lag',
#        'precipitation_sum_30d_lag', 'precipitation_sum_60d_lag',
#        'precipitation_sum_90d_lag', 'precipitation_sum_120d_lag',
#        'precipitation_sum_180d_lag', 'rain_sum_30d_lag', 'rain_sum_60d_lag',
#        'rain_sum_90d_lag', 'rain_sum_120d_lag', 'rain_sum_180d_lag',
#        'wind_speed_10m_max_30d_lag', 'wind_speed_10m_max_60d_lag',
#        'wind_speed_10m_max_90d_lag', 'wind_speed_10m_max_120d_lag',
#        'wind_speed_10m_max_180d_lag', 'et0_fao_evapotranspiration_30d_lag',
#        'et0_fao_evapotranspiration_60d_lag',
#        'et0_fao_evapotranspiration_90d_lag',
#        'et0_fao_evapotranspiration_120d_lag',
#        'et0_fao_evapotranspiration_180d_lag', 'season', 'heatwave_flag',
#        'coldwave_flag', 'heavy_rain_flag', 'temp_missing', 'USD_TL', 'trend',
#        'trends_missing', 'is_trend_zero'],
#       dtype='object')

# %%
df.to_csv(features_file, index=False)

# %%
df = pd.get_dummies(df, columns=['season'], prefix='season')

# %%
df.shape
# Out:
# (9862, 51)

# %%
ml_df = df.dropna(subset=['rolling_14d_adjusted'] + [c for c in df.columns if '_lag' in c])

# %%
ml_df.shape
# Out:
# (8769, 51)

# %%
ml_df.to_csv(ml_file, index=False)

# %%
ml_df.columns
# Out:
# Index(['Date', 'rolling_14d_adjusted', 'price_available', 'temperature_2m_max',
#        'temperature_2m_min', 'precipitation_sum', 'rain_sum',
#        'wind_speed_10m_max', 'et0_fao_evapotranspiration',
#        'temperature_2m_max_30d_lag', 'temperature_2m_max_60d_lag',
#        'temperature_2m_max_90d_lag', 'temperature_2m_max_120d_lag',
#        'temperature_2m_max_180d_lag', 'temperature_2m_min_30d_lag',
#        'temperature_2m_min_60d_lag', 'temperature_2m_min_90d_lag',
#        'temperature_2m_min_120d_lag', 'temperature_2m_min_180d_lag',
#        'precipitation_sum_30d_lag', 'precipitation_sum_60d_lag',
#        'precipitation_sum_90d_lag', 'precipitation_sum_120d_lag',
#        'precipitation_sum_180d_lag', 'rain_sum_30d_lag', 'rain_sum_60d_lag',
#        'rain_sum_90d_lag', 'rain_sum_120d_lag', 'rain_sum_180d_lag',
#        'wind_speed_10m_max_30d_lag', 'wind_speed_10m_max_60d_lag',
#        'wind_speed_10m_max_90d_lag', 'wind_speed_10m_max_120d_lag',
#        'wind_speed_10m_max_180d_lag', 'et0_fao_evapotranspiration_30d_lag',
#        'et0_fao_evapotranspiration_60d_lag',
#        'et0_fao_evapotranspiration_90d_lag',
#        'et0_fao_evapotranspiration_120d_lag',
#        'et0_fao_evapotranspiration_180d_lag', 'heatwave_flag', 'coldwave_flag',
#        'heavy_rain_flag', 'temp_missing', 'USD_TL', 'trend', 'trends_missing',
#        'is_trend_zero', 'season_development', 'season_harvest',
#        'season_off_season', 'season_spring'],
#       dtype='object')
